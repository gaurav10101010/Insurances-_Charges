# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\asus\Desktop\projects\insurance_cost\insurance\insurance.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.columns = ['age', 'gender', 'bmi', 'child', 'smoker', 'region', 'charges']

# %%
print("total female person : ",female.shape[0])
print("total male person : ",male.shape[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print("total female person : ",female.shape[0])
#       2 print("total male person : ",male.shape[1])
#
# NameError: name 'female' is not defined

# %%
df['gender'].value_counts()
# Out:
# gender
# male      676
# female    662
# Name: count, dtype: int64

# %%
df['child'].value_counts()
# Out:
# child
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
print(female['charges'].min())
print(female['charges'].max())
print(female['charges'].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(female['charges'].min())
#       2 print(female['charges'].max())
#       3 print(female['charges'].mean())
#
# NameError: name 'female' is not defined

# %%
print(male['charges'].min())
print(make['charges'].max())
print(male['charges'].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(male['charges'].min())
#       2 print(make['charges'].max())
#       3 print(male['charges'].mean())
#
# NameError: name 'male' is not defined

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
sns.relplot(x = df['bmi'],y = df['charges'] , hue = df['gender'], style= df['smoker'] ,data = df, col='region' )

# %%
sns.relplot(x = df['bmi'],y = df['charges'] , hue = df['gender'], style= df['smoker'] ,data = df, col='gender' )

# %%
df['child'].value_counts()
# Out:
# child
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
print(df['child'].min())
# Out:
# 0

# %%
child_group = df.groupby('child')
child_record = child_group['charges'].agg(min_price='min',max_price='max',avg_price='mean')

# %%
max_charges = df.groupby('child')['charges'].max().reset_index()
plt.figure(figsize=(8, 6))
sns.barplot(x='child', y='charges', data=max_charges)
plt.title('Maximum Charges for Each Number of Children')
plt.xlabel('Number of Children')
plt.ylabel('Maximum Charges')
plt.show()

# %%
df.select_dtype(include="O")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21408\446812409.py in ?()
# ----> 1 df.select_dtype(include="O")
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'select_dtype'

# %%
df2 = pd.get_dummies(df,drop_first='if_binary').astype(int)

# %%
df2.head()
# Out:
#    age  bmi  child  charges  gender_male  smoker_yes  region_northwest  \
# 0   19   27      0    16884            0           1                 0
# 1   18   33      1     1725            1           0                 0
# 2   28   33      3     4449            1           0                 0
# 3   33   22      0    21984            1           0                 1
# 4   32   28      0     3866            1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder,OneHotEncoder,OrdinalEncoder

# %%
obj = OneHotEncoder()
obj.fit_transform(cat_col).toarray()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 obj = OneHotEncoder()
# ----> 2 obj.fit_transform(cat_col).toarray()
#
# NameError: name 'cat_col' is not defined

# %%
x = df2.drop('charges',axis=1)
y = df2[['charges']]

# %%
x.head()
# Out:
#    age  bmi  child  gender_male  smoker_yes  region_northwest  \
# 0   19   27      0            0           1                 0
# 1   18   33      1            1           0                 0
# 2   28   33      3            1           0                 0
# 3   33   22      0            1           0                 1
# 4   32   28      0            1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.10)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.svm import SVC,SVR
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
lnr = LinearRegression()
dtr = DecisionTreeRegressor()
rdr = RandomForestRegressor(n_estimators=90,min_samples_split=20,min_samples_leaf=10)

## traaining algo's

lnr.fit(x_train,y_train)
print("linear regression is done")

dtr.fit(x_train,y_train)
print("decision tree regressor is done")

rdr.fit(x_train,y_train)
print("random forest regressor is done")

print("linear regresssion training score :",lnr.score(x_train,y_train)*100)
print("linear regresssion testing score : ",lnr.score(x_test,y_test)*100)

print()

print("decision tree regressor :",dtr.score(x_train,y_train)*100)
print("decision tree regressor : ",dtr.score(x_test,y_test)*100)

print()

print("random forest regressor :",rdr.score(x_train,y_train)*100)
print("random forest regressor : ",rdr.score(x_test,y_test)*100)
# Out:
# linear regression is done
# decision tree regressor is done
# random forest regressor is done
# linear regresssion training score : 74.15143085826898
# linear regresssion testing score :  83.21368868405644
#
# decision tree regressor : 99.77907115511242
# decision tree regressor :  84.11993470749664
#
# random forest regressor : 88.41289005420019
# random forest regressor :  91.04656167441676

# %%
import joblib,os
os.makedirs('models',exist_ok=True)
joblib.dump(lnr,'./models/linear_model')
joblib.dump(dtr,'./models/decisiontree')
joblib.dump(rdr,'./models/randomforest_model')
print("algos saved successfully")
# Out:
# algos saved successfully

# %%
### prediction

linear_prediction = lnr.predict(x_test)
decisiontree_prediction = dtr.predict(x_test)
randomforest_prediction = rdr.predict(x_test)

# %%
compare_df = pd.concat([x_test,y_test],axis = 'columns')
compare_df['linear_prediction'] = linear_prediction
compare_df['decsiontree_prediction'] = decisiontree_prediction
compare_df['randomforest_prediction']= randomforest_prediction

# %%
os.makedirs('prediction',exist_ok = True)
compare_df.to_csv('./prediction/prediction.csv',index = False)
print("succesfully saved your predictions")
# Out:
# succesfully saved your predictions

# %%
compare_df
# Out:
#       age  bmi  child  gender_male  smoker_yes  region_northwest  \
# 117    29   27      1            0           1                 0
# 1299   19   25      1            0           0                 1
# 1258   55   37      3            1           0                 1
# 1132   57   40      0            1           0                 0
# 45     55   37      0            1           0                 0
# ...   ...  ...    ...          ...         ...               ...
# 488    44   38      0            0           1                 0
# 1287   36   25      1            0           0                 0
# 216    53   26      0            0           0                 1
# 143    29   29      2            1           0                 1
# 308    58   34      0            1           0                 0
#
#       region_southeast  region_southwest  charges  linear_prediction  \
# 117                  1                 0    19107       28144.898042
# ...
